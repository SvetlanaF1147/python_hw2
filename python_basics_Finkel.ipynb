# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print (long_phrase > short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
x = int (input ('Введите объем файла в байтах '))
size_mb = x / (2**20)
print ('Объем файла равен',  size_mb,'Mb')
# Out:
# Введите объем файла в байтах 13644853
# Объем файла равен 13.01274585723877 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
# Вариант решения №1
x = input ('Введите месяц рождения ') #месяц
y = int (input ('Введите дату рождения ')) # дата

if (x.lower () == 'январь' and (20 <= y <= 31)) or (x.lower () == 'февраль' and (1 <= y <= 18)):
    print ('Водолей')
elif (x.lower () == 'январь' and (1 <= y <= 19)) or (x.lower () == 'декабрь' and (22 <= y <= 31)):
    print ('Козерог')
elif (x.lower () == 'февраль' and (19 <= y <= 29)) or (x.lower () == 'март' and (1 <= y <= 20)):
    print ('Рыбы')
elif (x.lower () == 'март' and (21 <= y <= 31)) or (x.lower () == 'апрель' and (1 <= y <= 19)):
    print ('Овен')
elif (x.lower () == 'апрель' and (20 <= y <= 30)) or (x.lower () == 'май' and (1 <= y <= 20)):
    print ('Телец')
elif (x.lower () == 'май' and (21 <= y <= 31)) or (x.lower () == 'июнь' and (1 <= y <= 20)):
    print ('Близнецы')
elif (x.lower () == 'июнь' and (21 <= y <= 30)) or (x.lower () == 'июль' and (1 <= y <= 22)):
    print ('Рак')
elif (x.lower () == 'июль' and (23 <= y <= 31)) or (x.lower () == 'август' and (1 <= y <= 22)):
    print ('Лев')
elif (x.lower () == 'август' and (23 <= y <= 31)) or (x.lower () == 'сентябрь' and (1 <= y <= 22)):
    print ('Дева')
elif (x.lower () == 'сентябрь' and (23 <= y <= 30)) or (x.lower () == 'октябрь' and (1 <= y <= 22)):
    print ('Весы')
elif (x.lower () == 'октябрь' and (23 <= y <= 31)) or (x.lower () == 'ноябрь' and (1 <= y <= 21)):
    print ('Скорпион')
elif (x.lower () == 'ноябрь' and (22 <= y <= 30)) or (x.lower () == 'декабрь' and (1 <= y <= 21)):
    print ('Стрелец')
else:
    print ('Некорректный ввод')

# %%
# Вариант решения №2
x = input ('Введите месяц рождения ') #месяц
y = int (input ('Введите дату рождения ')) # дата

if x.lower () == 'январь' and (20 <= y <= 31):
    print ('Водолей')
elif x.lower () == 'январь' and (1 <= y <= 19):
    print ('Козерог')
elif x.lower () == 'февраль' and (19 <= y <= 29):
    print ('Рыбы')
elif x.lower () == 'февраль' and (1 <= y <= 18):
    print ('Водолей')
elif x.lower () == 'март' and (21 <= y <= 31):
    print ('Овен')
elif x.lower () == 'март' and (1 <= y <= 20):
    print ('Рыбы')    
elif x.lower () == 'апрель' and (20 <= y <= 30):
    print ('Телец')
elif x.lower () == 'апрель' and (1 <= y <= 19):
    print ('Овен')
elif x.lower () == 'май' and (21 <= y <= 31):
    print ('Близнецы')
elif x.lower () == 'май' and (1 <= y <= 20):
    print ('Телец')
elif x.lower () == 'июнь' and (21 <= y <= 30):
    print ('Рак')
elif x.lower () == 'июнь' and (1 <= y <= 20):
    print ('Близнецы')
elif x.lower () == 'июль' and (23 <= y <= 31):
    print ('Лев')
elif x.lower () == 'июль' and (1 <= y <= 22):
    print ('Рак')    
elif x.lower () == 'август' and (23 <= y <= 31):
    print ('Дева')
elif x.lower () == 'август' and (1 <= y <= 22):
    print ('Лев')
elif x.lower () == 'сентябрь' and (23 <= y <= 30):
    print ('Весы')
elif x.lower () == 'сентябрь' and (1 <= y <= 22):
    print ('Дева')
elif x.lower () == 'октябрь' and (23 <= y <= 31):
    print ('Скорпион')
elif x.lower () == 'октябрь' and (1 <= y <= 22):
    print ('Весы')
elif x.lower () == 'ноябрь' and (22 <= y <= 30):
    print ('Стрелец')
elif x.lower () == 'ноябрь' and (1 <= y <= 21):
    print ('Скорпион')    
elif x.lower () == 'декабрь' and (22 <= y <= 31):
    print ('Козерог')
elif x.lower () == 'декабрь' and (1 <= y <= 21):
    print ('Стрелец')
else:
    print ('Некорректный ввод')

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
# x - сумма денег, потраченная на ипотеку;
# y - накопленная сумма


a = int (input ('Введите заработную плату за месяц (в рублях): '))
b = int (input ('Введите сколько процентов от заработной платы уходит на ипотеку: '))
c = int (input ('Введите сколько процентов от заработной платы уходит на жизнь: '))
n = int (input ('Введите количество премий за год: '))

x = a * 12 * (b / 100)
y = (a * 12 * ((100 - b - c) / 100)) + (a * n / 2)

print  ('На ипотеку было потрачено', x, 'рублей')
print  ('Было накоплено', y, 'рублей')
